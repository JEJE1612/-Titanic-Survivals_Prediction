# %% [markdown]
# #### =================

# %% [markdown]
# ## Full Data Science Project - Titanic Survivals Prediction[Classification]

# %% [markdown]
# ###### Predict Survival on Titanic and get familiar with ML basics

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### importing Dataset

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe().round(2)
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %% [markdown]
# ## Data Cleaning & Pr-processing

# %% [markdown]
# #### Dealing with Missing Data

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(titanic.isna())
plt.show()

# %%
titanic['Age']==titanic['Age'].fillna(titanic['Age'].mean())
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
titanic.drop('Cabin', axis = 1, inplace = True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
titanic['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sex = pd.get_dummies(titanic['Sex'], drop_first = True )
sex
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
emb = pd.get_dummies(titanic['Embarked']  )
emb
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [891 rows x 3 columns]

# %%
titanic['male']=sex

# %%
titanic.drop('Sex', axis=1, inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
titanic[['Q','S','C']] = emb

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
titanic.drop(['PassengerId','Name','Ticket','Embarked'] , axis=1, inplace = True)

# %%
titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S      C
# 0           0       3  22.0      1      0   7.2500   True  False  False   True
# 1           1       1  38.0      1      0  71.2833  False   True  False  False
# 2           1       3  26.0      0      0   7.9250  False  False  False   True
# 3           1       1  35.0      1      0  53.1000  False  False  False   True
# 4           0       3  35.0      0      0   8.0500   True  False  False   True
# ..        ...     ...   ...    ...    ...      ...    ...    ...    ...    ...
# 886         0       2  27.0      0      0  13.0000   True  False  False   True
# 887         1       1  19.0      0      0  30.0000  False  False  False   True
# 888         0       3   NaN      1      2  23.4500  False  False  False   True
# 889         1       1  26.0      0      0  30.0000   True   True  False  False
# 890         0       3  32.0      0      0   7.7500   True  False   True  False
#
# [891 rows x 10 columns]

# %%
titanic.rename(columns={'male':'Gander'},inplace= True)

# %%
titanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Gander      Q      S  \
# 0           0       3  22.0      1      0   7.2500    True  False  False
# 1           1       1  38.0      1      0  71.2833   False   True  False
# 2           1       3  26.0      0      0   7.9250   False  False  False
# 3           1       1  35.0      1      0  53.1000   False  False  False
# 4           0       3  35.0      0      0   8.0500    True  False  False
# ..        ...     ...   ...    ...    ...      ...     ...    ...    ...
# 886         0       2  27.0      0      0  13.0000    True  False  False
# 887         1       1  19.0      0      0  30.0000   False  False  False
# 888         0       3   NaN      1      2  23.4500   False  False  False
# 889         1       1  26.0      0      0  30.0000    True   True  False
# 890         0       3  32.0      0      0   7.7500    True  False   True
#
#          C
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# ..     ...
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(x='Survived', data=titanic ,palette = 'pastel')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8508\2518788321.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=titanic ,palette = 'pastel')

# %%
sns.countplot(x='Survived', data = titanic , hue='Gander', palette = 'pastel')
plt.show()

# %%
titanic['Age'].hist(bins=30)
plt.show()

# %%
titanic['Fare'].hist()
plt.show()

# %%
sns.distplot(titanic)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8508\500547939.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic)

# %% [markdown]
# ## Building Our Model

# %% [markdown]
# ##### Train/ Test Split Data

# %%
x = titanic.drop('Survived',axis = 1)
y = titanic['Survived']

# %%
x
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Gander      Q      S      C
# 0         3  22.0      1      0   7.2500    True  False  False   True
# 1         1  38.0      1      0  71.2833   False   True  False  False
# 2         3  26.0      0      0   7.9250   False  False  False   True
# 3         1  35.0      1      0  53.1000   False  False  False   True
# 4         3  35.0      0      0   8.0500    True  False  False   True
# ..      ...   ...    ...    ...      ...     ...    ...    ...    ...
# 886       2  27.0      0      0  13.0000    True  False  False   True
# 887       1  19.0      0      0  30.0000   False  False  False   True
# 888       3   NaN      1      2  23.4500   False  False  False   True
# 889       1  26.0      0      0  30.0000    True   True  False  False
# 890       3  32.0      0      0   7.7500    True  False   True  False
#
# [891 rows x 9 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %% [raw]
# x_train, x_test,y_train , y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (712, 9)

# %%
x_test.shape
# Out:
# (179, 9)

# %%
y_train.shape
# Out:
# (712,)

# %%
y_test.shape
# Out:
# (179,)

# %% [markdown]
# #### Model Training and Predicting

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
imputer = SimpleImputer(strategy='mean')
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

# %%
model = LogisticRegression()
model.fit(x_train_imputed, y_train)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_paid = model.predict(x_test_imputed)

# %%
print(len(y_test), len(y_paid))
# Out:
# 179 179

# %%
confusion = confusion_matrix(y_test, y_paid)
print(confusion)
# Out:
# [[89 16]
#  [19 55]]

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test, y_paid)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.82      0.85      0.84       105\n           1       0.77      0.74      0.76        74\n\n    accuracy                           0.80       179\n   macro avg       0.80      0.80      0.80       179\nweighted avg       0.80      0.80      0.80       179\n'

# %% [markdown]
# #### ====================
